# %%
import os
import sys

module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from framework.parser.pandas_parser import parse_dataframe_as_items
from framework.property import CategoricalProperty, NumericalProperty

import pandas as pd
frame = pd.read_csv("../../Datasets/Temp/train.csv")

mapping = {
    "MSSubClass": CategoricalProperty,
    "MSZoning": CategoricalProperty,
    "LotFrontage": NumericalProperty,
    "LotArea": NumericalProperty,
    "Street": CategoricalProperty,
    "Alley": CategoricalProperty,
    "LotShape": CategoricalProperty,
    "LandContour": CategoricalProperty,
    "Utilities": CategoricalProperty,
    "LotConfig": CategoricalProperty,
    "LandSlope": CategoricalProperty,
    "Neighborhood": CategoricalProperty,
    "Condition1": CategoricalProperty,
    "Condition2": CategoricalProperty,
    "BldgType": CategoricalProperty,
    "HouseStyle": CategoricalProperty
}

items_og = parse_dataframe_as_items(frame, mapping, id_col="Id")

# %%
# %%prun -D evaluate.prof
from framework.evaluate.evaluate import simple_evaluation
from framework.recommender.critiquing.housing_critiquing_recommender import ImplementedCritiquingRecommender

recommender = ImplementedCritiquingRecommender(items_og, method="intersection")
simple_evaluation(recommender)
# Out:
# Goal is in items: True
# Staring item: <id:253, properties:{'MSSubClass': '60', 'MSZoning': 'RL', 'LotFrontage': '65.0', 'LotArea': '8366.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'Inside', 'LandSlope': 'Gtl', 'Neighborhood': 'SawyerW', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '2Story'}>
# Goal: <id:335, properties:{'MSSubClass': '60', 'MSZoning': 'RL', 'LotFrontage': '59.0', 'LotArea': '9042.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'Inside', 'LandSlope': 'Gtl', 'Neighborhood': 'Gilbert', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '2Story'}>
#
# --------------------------------------------------
# Selected critique: [<Prop: 'LotFrontage' Critique: <DirectionalCritique> DirectionalCritiqueDirections.SMALLER (for 65.0)>,<Prop: 'Neighborhood' Critique: <NotCritique> (for SawyerW)>]
# Goal is still in items: True
# New anchor: <id:1275, properties:{'MSSubClass': '50', 'MSZoning': 'RL', 'LotFrontage': '53.0', 'LotArea': '5362.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'Reg', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'Corner', 'LandSlope': 'Gtl', 'Neighborhood': 'Crawfor', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '1.5Fin'}>
# --------------------------------------------------
# --------------------------------------------------
# Selected critique: [<Prop: 'LotShape' Critique: <NotCritique> (for Reg)>,<Prop: 'MSSubClass' Critique: <NotCritique> (for 50)>,<Prop: 'Neighborhood' Critique: <NotCritique> (for Crawfor)>,<Prop: 'LotConfig' Critique: <NotCritique> (for Corner)>]
# Goal is still in items: True
# New anchor: <id:559, properties:{'MSSubClass': '60', 'MSZoning': 'RL', 'LotFrontage': '57.0', 'LotArea': '21872.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR2', 'LandContour': 'HLS', 'Utilities': 'AllPub', 'LotConfig': 'FR2', 'LandSlope': 'Gtl', 'Neighborhood': 'Gilbert', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '2Story'}>
# --------------------------------------------------
# --------------------------------------------------
# Selected critique: [<Prop: 'LotConfig' Critique: <NotCritique> (for FR2)>,<Prop: 'LotArea' Critique: <DirectionalCritique> DirectionalCritiqueDirections.SMALLER (for 21872.0)>,<Prop: 'LotShape' Critique: <NotCritique> (for IR2)>,<Prop: 'LandContour' Critique: <NotCritique> (for HLS)>]
# Goal is still in items: True
# New anchor: <id:195, properties:{'MSSubClass': '20', 'MSZoning': 'RL', 'LotFrontage': '60.0', 'LotArea': '7180.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'Inside', 'LandSlope': 'Gtl', 'Neighborhood': 'CollgCr', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '1Story'}>
# --------------------------------------------------
# --------------------------------------------------
# Selected critique: [<Prop: 'HouseStyle' Critique: <NotCritique> (for 1Story)>,<Prop: 'Neighborhood' Critique: <NotCritique> (for CollgCr)>,<Prop: 'LotFrontage' Critique: <DirectionalCritique> DirectionalCritiqueDirections.SMALLER (for 60.0)>]
# Goal is still in items: True
# New anchor: <id:1410, properties:{'MSSubClass': '60', 'MSZoning': 'RL', 'LotFrontage': '46.0', 'LotArea': '20544.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'CulDSac', 'LandSlope': 'Gtl', 'Neighborhood': 'NWAmes', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '2Story'}>
# --------------------------------------------------
# --------------------------------------------------
# Selected critique: [<Prop: 'LotConfig' Critique: <NotCritique> (for CulDSac)>,<Prop: 'LotArea' Critique: <DirectionalCritique> DirectionalCritiqueDirections.SMALLER (for 20544.0)>]
# Goal is still in items: True
# New anchor: <id:128, properties:{'MSSubClass': '45', 'MSZoning': 'RM', 'LotFrontage': '55.0', 'LotArea': '4388.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Bnk', 'Utilities': 'AllPub', 'LotConfig': 'Inside', 'LandSlope': 'Gtl', 'Neighborhood': 'OldTown', 'Condition1': 'Feedr', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '1.5Unf'}>
# --------------------------------------------------
# --------------------------------------------------
# Selected critique: [<Prop: 'MSSubClass' Critique: <NotCritique> (for 45)>,<Prop: 'MSZoning' Critique: <NotCritique> (for RM)>]
# Goal is still in items: True
# New anchor: <id:545, properties:{'MSSubClass': '60', 'MSZoning': 'RL', 'LotFrontage': '58.0', 'LotArea': '17104.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'Inside', 'LandSlope': 'Gtl', 'Neighborhood': 'Gilbert', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '2Story'}>
# --------------------------------------------------
# --------------------------------------------------
# Selected critique: <Prop: 'LotFrontage' Critique: <DirectionalCritique> DirectionalCritiqueDirections.GREATER (for 58.0)>
# Goal is still in items: True
# New anchor: <id:1259, properties:{'MSSubClass': '80', 'MSZoning': 'RL', 'LotFrontage': '59.0', 'LotArea': '9587.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'Inside', 'LandSlope': 'Gtl', 'Neighborhood': 'Gilbert', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': 'SLvl'}>
# --------------------------------------------------
# --------------------------------------------------
# Selected critique: [<Prop: 'MSSubClass' Critique: <NotCritique> (for 80)>,<Prop: 'LotArea' Critique: <DirectionalCritique> DirectionalCritiqueDirections.SMALLER (for 9587.0)>]
# Goal is still in items: True
# New anchor: <id:335, properties:{'MSSubClass': '60', 'MSZoning': 'RL', 'LotFrontage': '59.0', 'LotArea': '9042.0', 'Street': 'Pave', 'Alley': 'None', 'LotShape': 'IR1', 'LandContour': 'Lvl', 'Utilities': 'AllPub', 'LotConfig': 'Inside', 'LandSlope': 'Gtl', 'Neighborhood': 'Gilbert', 'Condition1': 'Norm', 'Condition2': 'Norm', 'BldgType': '1Fam', 'HouseStyle': '2Story'}>
# --------------------------------------------------
# Amount of interactions: 8
#
# *** Profile stats marshalled to file 'evaluate.prof'.
#          304209147 function calls (304208776 primitive calls) in 63.549 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 144109617   29.882    0.000   36.521    0.000 item.py:24(__eq__)
#    156685   12.993    0.000   33.675    0.000 dynamic_critique_generator.py:94(<genexpr>)
#      1868    6.844    0.004   51.344    0.027 dynamic_critique_generator.py:89(_get_common_supporting_items)
# 145335062    6.815    0.000    6.994    0.000 {built-in method builtins.isinstance}
#      1644    3.282    0.002   10.585    0.006 critique_recommender.py:18(get_passing_items_for_critique)
#   1064737    0.890    0.000    1.278    0.000 item_critique.py:55(__eq__)
#    701681    0.319    0.000    1.611    0.000 item_critique.py:13(passes_critique)
#   1050282    0.266    0.000    0.611    0.000 property_interface.py:38(__eq__)
#    525125    0.261    0.000    0.872    0.000 not_critique.py:8(passes_critique)
#   4351172    0.215    0.000    0.215    0.000 {built-in method builtins.len}
#   1041313    0.211    0.000    1.822    0.000 item_critique.py:50(<genexpr>)
#    339647    0.194    0.000    2.131    0.000 item_critique.py:49(passes_critique)
#   1122110    0.190    0.000    0.190    0.000 {method 'intersection' of 'set' objects}
#         8    0.170    0.021   56.520    7.065 dynamic_critique_generator.py:12(apriori)
#    701681    0.157    0.000    0.272    0.000 item.py:39(__getitem__)
#    339647    0.116    0.000    1.911    0.000 {built-in method builtins.all}
#    701681    0.115    0.000    0.115    0.000 item.py:12(get_prop)
#    525131    0.098    0.000    0.180    0.000 abc.py:96(__instancecheck__)
#     94998    0.092    0.000    2.206    0.000 critique_recommender.py:23(<genexpr>)
#    176556    0.083    0.000    0.148    0.000 directional_critique.py:40(passes_critique)
#    525131    0.081    0.000    0.081    0.000 {built-in method _abc._abc_instancecheck}
#    483017    0.081    0.000    0.123    0.000 item.py:21(__hash__)
#    172226    0.053    0.000    0.064    0.000 comparable_property.py:13(__lt__)
# 483473/483169    0.043    0.000    0.043    0.000 {built-in method builtins.hash}
#         8    0.025    0.003    0.075    0.009 housing_critiquing_recommender.py:26(select_critique)
#     57373    0.012    0.000    0.024    0.000 item_critique.py:65(get_common_prop_critiques_of_compounds)
#     12025    0.012    0.000    0.019    0.000 dynamic_critique_generator.py:86(_have_overlapping_props_for_crits)
#      1532    0.010    0.000    0.102    0.000 {method 'add' of 'set' objects}
#     12025    0.008    0.000    0.016    0.000 item_critique.py:77(combine_compound_crits)
#     36075    0.005    0.000    0.005    0.000 dynamic_critique_generator.py:87(<genexpr>)
#     12177    0.004    0.000    0.005    0.000 item_critique.py:30(__init__)
#     12025    0.004    0.000    0.004    0.000 {method 'union' of 'set' objects}
#     12025    0.003    0.000    0.003    0.000 {method 'symmetric_difference' of 'set' objects}
#     12025    0.003    0.000    0.006    0.000 item_critique.py:73(get_prop_critiques_sym_difference_of_compounds)
#     25175    0.002    0.000    0.002    0.000 item_critique.py:61(__hash__)
#      1492    0.001    0.000    6.942    0.005 critique_recommender.py:9(get_support_for_critique)
#      4330    0.001    0.000    0.002    0.000 comparable_property.py:19(__gt__)
#        95    0.001    0.000    0.001    0.000 socket.py:342(send)
#         1    0.001    0.001   63.549   63.549 evaluate.py:6(simple_evaluation)
#       709    0.001    0.000    0.011    0.000 housing_critiquing_recommender.py:29(<genexpr>)
#         8    0.001    0.000    6.942    0.868 housing_critiquing_recommender.py:34(<listcomp>)
#         8    0.000    0.000    3.647    0.456 critique_recommender.py:16(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#       128    0.000    0.000    0.001    0.000 unit_critique_generator.py:17(get_critiques_for_prop)
#         8    0.000    0.000    0.001    0.000 dynamic_critique_generator.py:16(<dictcomp>)
#   265/198    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        90    0.000    0.000    0.002    0.000 iostream.py:386(write)
#        95    0.000    0.000    0.001    0.000 iostream.py:197(schedule)
#         8    0.000    0.000    0.001    0.000 dynamic_critique_generator.py:15(<dictcomp>)
#         8    0.000    0.000    0.001    0.000 unit_critique_generator.py:4(generate_valid_critiques)
#      1492    0.000    0.000    0.000    0.000 housing_critiquing_recommender.py:35(<lambda>)
#         8    0.000    0.000   63.463    7.933 housing_critiquing_recommender.py:20(get_critiques_for_anchor)
#        16    0.000    0.000    0.000    0.000 unit_critique_generator.py:30(_create_parameter_args_permutations)
#        90    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        10    0.000    0.000    0.000    0.000 item.py:19(<dictcomp>)
#        95    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#        45    0.000    0.000    0.002    0.000 {built-in method builtins.print}
#       152    0.000    0.000    0.000    0.000 property_interface.py:46(__hash__)
#         8    0.000    0.000    0.000    0.000 dynamic_critique_generator.py:14(<listcomp>)
#         8    0.000    0.000    0.000    0.000 housing_critiquing_recommender.py:36(<listcomp>)
#       120    0.000    0.000    0.000    0.000 not_critique.py:5(__init__)
#         3    0.000    0.000    0.000    0.000 random.py:315(sample)
#        32    0.000    0.000    0.000    0.000 item_critique.py:19(__eq__)
#         1    0.000    0.000   63.549   63.549 {built-in method builtins.exec}
#       180    0.000    0.000    0.000    0.000 property_interface.py:36(__str__)
#        90    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#       152    0.000    0.000    0.000    0.000 item_critique.py:26(__hash__)
#        95    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        73    0.000    0.000    0.000    0.000 random.py:250(_randbelow_with_getrandbits)
#        10    0.000    0.000    0.000    0.000 item.py:18(__str__)
#        95    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#       152    0.000    0.000    0.000    0.000 critique_interface.py:26(__hash__)
#        48    0.000    0.000    0.000    0.000 unit_critique_generator.py:39(<genexpr>)
#        95    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#       152    0.000    0.000    0.000    0.000 item_critique.py:9(__init__)
#         8    0.000    0.000    6.943    0.868 housing_critiquing_recommender.py:33(sort_by_support)
#       320    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       152    0.000    0.000    0.000    0.000 critique_interface.py:5(__init__)
#       128    0.000    0.000    0.000    0.000 property_interface.py:20(get_valid_critiques)
#        90    0.000    0.000    0.000    0.000 iostream.py:323(_schedule_flush)
#        32    0.000    0.000    0.000    0.000 directional_critique.py:35(__init__)
#         8    0.000    0.000    0.000    0.000 housing_critiquing_recommender.py:16(recommend_items)
#        32    0.000    0.000    0.000    0.000 critique_interface.py:23(__eq__)
#         1    0.000    0.000   63.549   63.549 <string>:1(<module>)
#        95    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#        66    0.000    0.000    0.000    0.000 dynamic_critique_generator.py:19(<genexpr>)
#       120    0.000    0.000    0.000    0.000 critique_interface.py:15(get_description_parameters)
#        16    0.000    0.000    0.000    0.000 enum.py:346(__iter__)
#         7    0.000    0.000    0.000    0.000 item_critique.py:53(<listcomp>)
#        48    0.000    0.000    0.000    0.000 enum.py:347(<genexpr>)
#        10    0.000    0.000    0.000    0.000 random.py:285(choice)
#         6    0.000    0.000    0.000    0.000 enum.py:626(__format__)
#         7    0.000    0.000    0.000    0.000 item_critique.py:52(__str__)
#        95    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        96    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#        32    0.000    0.000    0.000    0.000 unit_critique_generator.py:39(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 enum.py:614(__str__)
#        16    0.000    0.000    0.000    0.000 directional_critique.py:47(get_description_parameters)
#        16    0.000    0.000    0.000    0.000 enum.py:349(__len__)
#        20    0.000    0.000    0.000    0.000 item_critique.py:16(__str__)
#        42    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         8    0.000    0.000    3.647    0.456 critique_recommender.py:12(get_passing_items_for_critiques)
#        73    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#        32    0.000    0.000    0.000    0.000 unit_critique_generator.py:33(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#        14    0.000    0.000    0.000    0.000 not_critique.py:14(__str__)
#         3    0.000    0.000    0.000    0.000 {built-in method math.log}
#         8    0.000    0.000    0.000    0.000 critiquing_recommender_interface.py:26(select_critique)
#         8    0.000    0.000    0.000    0.000 item.py:15(iter_props)
#        25    0.000    0.000    0.000    0.000 critiquing_recommender_interface.py:9(get_anchor)
#         9    0.000    0.000    0.000    0.000 critiquing_recommender_interface.py:12(set_anchor)
#        32    0.000    0.000    0.000    0.000 unit_critique_generator.py:34(<genexpr>)
#         7    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         3    0.000    0.000    0.000    0.000 abc.py:100(__subclasscheck__)
#         6    0.000    0.000    0.000    0.000 directional_critique.py:56(__str__)
#         1    0.000    0.000    0.000    0.000 housing_critiquing_recommender.py:12(__init__)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:302(__subclasshook__)
#         6    0.000    0.000    0.000    0.000 {method '__format__' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 critiquing_recommender_interface.py:4(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
